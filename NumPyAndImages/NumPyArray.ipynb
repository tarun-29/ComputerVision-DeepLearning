# %%
import numpy as np
import matplotlib.pyplot as plt #it allow to display image inside notebook
from PIL import Image

# %%
pic = Image.open('../DATA/00-puppy.jpg')
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()
#only red (1300,1950,0)
plt.imshow(pic_red[:,:,0])

# %%
plt.imshow(pic_red[:,:,1])

# %%
plt.imshow(pic_red[:,:,2])

# %%
plt.imshow(pic_red[:,:,0],cmap='gray')

# %%
pic_red[:,:,1] = 0
plt.imshow(pic_red)
